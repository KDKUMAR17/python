# %%
str='Thala'
print(str.upper())
print(str.lower())
print(str.swapcase())
# Out:
# THALA
# thala
# tHALA

# %%
str="to day is good day"
print(str.capitalize())
print(str.title())
# Out:
# To day is good day
# To Day Is Good Day

# %%
txt = "Hello, welcome to my world."

x = txt.index("e", 9, 20)

print(x)
# Out:
# 13

# %%
txt = "Hello, welcome to my world."
print(txt.count('Q'))
# Out:
# 0

# %%
txt = "Hello, welcome to my world."

x = txt.find("e", 9, 20)

print(x)
# Out:
# 13

# %%
txt = ",,,,,rrttgg.....banana....rrr"

x = txt.strip(",.grt")

print(x)
# Out:
# banana

# %%
txt = ",,,,,ssaaww.....6banana"

x = txt.lstrip(",6.asw")

print(x)
# Out:
# banana

# %%
txt = "banana"

x = txt.center(20, "O")

print(x)
# Out:
# OOOOOOObananaOOOOOOO

# %%
txt = "banana"

x = txt.ljust(20, "O")

print(x)
# Out:
# bananaOOOOOOOOOOOOOO

# %%
txt = "banana"

x = txt.rjust(20, "O")

print(x)
# Out:
# OOOOOOOOOOOOOObanana
