# %%
#Login validation
credentials={"dinesh":"123@123","chinky":"yk@ky","dhanush":"Diament","pankaj":"@123"}
user_name=(input("Enter user name :"))
password=(input("Enter user Password :"))
if user_name in credentials:
    actul_password=credentials[user_name]
    if password==actul_password:
        print("Login Successfull")
        print(user_name)
    else:
        print("Password is wrong")
else:
    print("User name  not existing")
# Out:
# Enter user name : poiu
# Enter user Password : 123@123
# User name  not existing

# %%
#greatest of three numbers
num1=int(input("Enter the number 1 :"))
num2=int(input("Enter the number 2 :"))
num3=int(input("Enter the number 3 :"))
if num1>num2:
    if num1>num3:
        print(f'{num1} is greatest')
    else:
        print(f'{num3} is greatest')
elif num2>num1:
    if num2>num3:
         print(f'{num2} is greatest')
    else:
        print(f'{num3} is greatest')
else:
     print(f'{num3} is greatest')
# Out:
# Enter the number 1 : 12
# Enter the number 2 : 6
# Enter the number 3 : -9
# 12 is greatest
