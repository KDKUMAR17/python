# %%
# 1.print the square of a given integer number
num=int(input("Enter the number:"))
print(f"{num} squre is {num**2}")
# Out:
# Enter the number: 5
# 5 squre is 25

# %%
# 2.find the product of two float numbers
num1,num2=float(input("Enter the Float Number1:")),float(input("Enter the Float Number2:"))
print(f"{num1} and {num2} product is {num1*num2}")
# Out:
# Enter the Float Number1: 9.6
# Enter the Float Number2: 5.3
# 9.6 and 5.3 product is 50.879999999999995

# %%
# 3.find the area of a rectangle.
length=int(input("Enter the Length"))
width=int(input("Enter the width"))
print(f"area of a rectangle is {length* width}")
# Out:
# Enter the Length 7
# Enter the width 9
# area of a rectangle is 63

# %%
# 4.reverse the given string.
str=input("enter the string :")
print(f'revers a string is "{str[::-1]}"')
# Out:
# enter the string : dinesh
# revers a string is "hsenid"

# %%
# 6. find the simple interest.
amount=int(input("enter the princpal"))
intrest=int(input("enter the intrest rate "))
time=int(input("enter the time"))
print(F"Simple intrest is {amount*intrest*time/100}")
# Out:
# enter the princpal 10000
# enter the intrest rate  2
# enter the time 5
# Simple intrest is 1000.0

# %%
# Three sides of the triangle is a, b and c:  
a = float(input('Enter first side: '))  
b = float(input('Enter second side: '))  
c = float(input('Enter third side: '))  
  
# calculate the semi-perimeter  
s = (a + b + c) / 2  
  
# calculate the area  
area = (s*(s-a)*(s-b)*(s-c)) ** 0.5  
print('The area of the triangle is %0.2f' %area)
# Out:
# Enter first side:  5
# Enter second side:  7
# Enter third side:  9
# The area of the triangle is 17.41
