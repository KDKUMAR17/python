# %%
collection=[1,3,4,5,9,10,16]
result=map(lambda num: num**2,collection)
print(list(result))
# Out:
# [1, 9, 16, 25, 81, 100, 256]

# %%
res=filter(lambda num : True if num%2==0 else False,collection)
print(list(res))
# Out:
# [4, 10, 16]
