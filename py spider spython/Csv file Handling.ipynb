# %%
import csv

# %%
file=open("employe.csv",'r')
readobj=csv.reader(file)
for line in readobj:
    if readobj.line_num %2==0:
        print(next(readobj))
file.close()
# Out:
# ['7499', 'ALLEN', 'SALESMAN', '7698', '20-FEB-81', '1600', '300', '30']
# ['7566', 'JONES', 'MANAGER', '7839', '02-APR-81', '2975', '0', '20']
# ['7698', 'BLAKE', 'MANAGER', '7839', '01-MAY-81', '2850', '0', '30']
# ['7788', 'SCOTT', 'ANALYST', '7566', '19-APR-87', '3000', '0', '20']
# ['7844', 'TURNER', 'SALESMAN', '7698', '08-SEP-81', '1500', '0', '30']
# ['7900', 'JAMES', 'CLERK', '7698', '03-DEC-81', '950', '0', '30']
# ['7934', 'MILLER', 'CLERK', '7782', '23-JAN-82', '1300', '0', '10']

# %%
file=open("employe.csv",'r')
readobj=csv.reader(file)

sal=[]
next(readobj)
for line in readobj:
        sal.append(int(line[5]))
        
max_sal=max(sal)

file.close()
file=open("employe.csv",'r')
read_obj=csv.reader(file)
read_obj=csv.reader(file)
next(read_obj)
for line in read_obj:
        
        if max_sal==int(line[5]):
                print(line[1])
file.close()
# Out:
# KING

# %%
file=open("employe.csv",'r')
readobj=csv.reader(file)

sal=[]
next(readobj)

for line in readobj:
        sal.append(int(line[5]))
avg=sum(sal)/len(sal)
print(avg)
file.close()
# Out:
# 2073.214285714286

# %%
file=open("employe.csv",'r')
readobj=csv.reader(file)

name=[]
next(readobj)

for line in readobj:
        sal.append(line[1])
print(name)
# Out:
# []

# %%
with open('EVENT.log') as file1:
        s=file1.read()
        print(s)
# Out:
# 03/22 08:53:53 EVENT  :..mailslot_sitter: process received signal SIGALRM
# 03/22 08:54:09 EVENT  :..mailslot_sitter: process received signal SIGALRM
# 03/22 08:54:24 EVENT  :..mailslot_sitter: process received signal SIGALRM
