# %%
#check leape year
y=int(input("enter year"))
if(y%4==0 and y%100 !=0)or(y%400==0):
    print(y,"leape year")
else:
    print(y,'not leape year')
# Out:
# enter year1900
# 1900 not leape year

# %%
# decressing outer trangle
n=int (input ("enter the number"));
for i in range(n):
    for j in range(n):
        if i==j or i==0 or j==n-1:
            print('* ',end="")
        else:
            print(' ',end=' ')
    print()
# Out:
# enter the number8
# * * * * * * * *
#   *           *
#     *         *
#       *       *
#         *     *
#           *   *
#             * *
#               *

# %%
n=int(input("enter"))
for i in range(n+1):
    for j in range(n):
        if j==0 or i==0 or i==n//2:
            print('* ',end="")
        else:
            print(" ",end=' ')
    print()
# Out:
# enter7
# * * * * * * *
# *
# *
# * * * * * * *
# *
# *
# *
# *

# %%
n=int(input("enter"))
for i in range(n):
    for j in range(n):
        if i==0 or j==0 or i==n//2 or i==n-1:
               print('* ',end="")
        else:
            print(" ",end=' ')
    print()
# Out:
# enter7
# * * * * * * *
# *
# *
# * * * * * * *
# *
# *
# * * * * * * *

# %%
n=int(input('enter'))
f=1
for i in range(1,n+1):
    f=f*i
print(f)
# Out:
# enter5
# 120

# %%
n=int(input("enter your number"))
